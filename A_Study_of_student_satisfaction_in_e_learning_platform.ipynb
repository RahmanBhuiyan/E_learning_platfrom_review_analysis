# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import pandas as pd 
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt
import numpy as np
import plotly.graph_objects as go
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/kaggle-survey-report/kaggle_survey_2022_responses.csv
# /kaggle/input/online-education-system-review/ONLINE EDUCATION SYSTEM REVIEW.csv

# %% [markdown]
# # Data Collection

# %%
df=pd.read_csv("/kaggle/input/online-education-system-review/ONLINE EDUCATION SYSTEM REVIEW.csv")
data=pd.read_csv("/kaggle/input/kaggle-survey-report/kaggle_survey_2022_responses.csv")
data
# Out:
# /opt/conda/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3552: DtypeWarning: Columns (0,208,225,255,257,260,270,271,277) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#        Duration (in seconds)                           Q2  \
# 0      Duration (in seconds)  What is your age (# years)?
# 1                        121                        30-34
# 2                        462                        30-34
# 3                        293                        18-21
# 4                        851                        55-59
# ...                      ...                          ...
# 23993                    331                        22-24
# 23994                    330                        60-69
# 23995                    860                        25-29
# 23996                    597                        35-39
# 23997                    303                        18-21
#
#                                            Q3  \
# 0      What is your gender? - Selected Choice
# 1                                         Man
# 2                                         Man
# 3                                         Man
# 4                                         Man
# ...                                       ...
# 23993                                     Man
# 23994                                     Man
# 23995                                     Man
# 23996                                   Woman
# 23997                                     Man
#
#                                               Q4  \
# 0      In which country do you currently reside?
# 1                                          India
# 2                                        Algeria
# 3                                          Egypt
# 4                                         France
# ...                                          ...
# 23993                   United States of America
# 23994                   United States of America
# 23995                                     Turkey
# 23996                                     Israel
# 23997                                      India
#
#                                                       Q5  \
# 0      Are you currently a student? (high school, uni...
# 1                                                     No
# 2                                                     No
# 3                                                    Yes
# 4                                                     No
# ...                                                  ...
# 23993                                                Yes
# 23994                                                Yes
# 23995                                                 No
# 23996                                                 No
# 23997                                                Yes
#
#                                                     Q6_1  \
# 0      On which platforms have you begun or completed...
# 1                                                    NaN
# 2                                                    NaN
# 3                                               Coursera
# 4                                               Coursera
# ...                                                  ...
# 23993                                                NaN
# 23994                                                NaN
# 23995                                                NaN
# 23996                                                NaN
# 23997                                                NaN
#
#                                                     Q6_2  \
# 0      On which platforms have you begun or completed...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    edX
# 4                                                    NaN
# ...                                                  ...
# 23993                                                NaN
# 23994                                                NaN
# 23995                                                NaN
# 23996                                                NaN
# 23997                                                NaN
#
#                                                     Q6_3  \
# 0      On which platforms have you begun or completed...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                   Kaggle Learn Courses
# ...                                                  ...
# 23993                                                NaN
# 23994                                                NaN
# 23995                                                NaN
# 23996                               Kaggle Learn Courses
# 23997                                                NaN
#
#                                                     Q6_4  \
# 0      On which platforms have you begun or completed...
# 1                                                    NaN
# 2                                                    NaN
# 3                                               DataCamp
# 4                                                    NaN
# ...                                                  ...
# 23993                                                NaN
# 23994                                                NaN
# 23995                                           DataCamp
# 23996                                                NaN
# 23997                                                NaN
#
#                                                     Q6_5  ...  \
# 0      On which platforms have you begun or completed...  ...
# 1                                                    NaN  ...
# 2                                                    NaN  ...
# 3                                                    NaN  ...
# 4                                                    NaN  ...
# ...                                                  ...  ...
# 23993                                                NaN  ...
# 23994                                                NaN  ...
# 23995                                                NaN  ...
# 23996                                                NaN  ...
# 23997                                                NaN  ...
#
#                                                    Q44_3  \
# 0      Who/what are your favorite media sources that ...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 23993                                                NaN
# 23994                                                NaN
# 23995                                                NaN
# 23996                                                NaN
# 23997                                                NaN
#
#                                                    Q44_4  \
# 0      Who/what are your favorite media sources that ...
# 1                                                    NaN
# 2                                                    NaN
# 3                        Kaggle (notebooks, forums, etc)
# 4                        Kaggle (notebooks, forums, etc)
# ...                                                  ...
# 23993                    Kaggle (notebooks, forums, etc)
# 23994                                                NaN
# 23995                    Kaggle (notebooks, forums, etc)
# 23996                                                NaN
# 23997                                                NaN
#
#                                                    Q44_5  \
# 0      Who/what are your favorite media sources that ...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4      Course Forums (forums.fast.ai, Coursera forums...
# ...                                                  ...
# 23993                                                NaN
# 23994                                                NaN
# 23995                                                NaN
# 23996                                                NaN
# 23997                                                NaN
#
#                                                    Q44_6  \
# 0      Who/what are your favorite media sources that ...
# 1                                                    NaN
# 2                                                    NaN
# 3      YouTube (Kaggle YouTube, Cloud AI Adventures, ...
# 4                                                    NaN
# ...                                                  ...
# 23993  YouTube (Kaggle YouTube, Cloud AI Adventures, ...
# 23994  YouTube (Kaggle YouTube, Cloud AI Adventures, ...
# 23995  YouTube (Kaggle YouTube, Cloud AI Adventures, ...
# 23996  YouTube (Kaggle YouTube, Cloud AI Adventures, ...
# 23997                                                NaN
#
#                                                    Q44_7  \
# 0      Who/what are your favorite media sources that ...
# 1                                                    NaN
# 2                                                    NaN
# 3      Podcasts (Chai Time Data Science, O’Reilly Dat...
# 4                                                    NaN
# ...                                                  ...
# 23993  Podcasts (Chai Time Data Science, O’Reilly Dat...
# 23994                                                NaN
# 23995                                                NaN
# 23996                                                NaN
# 23997                                                NaN
#
#                                                    Q44_8  \
# 0      Who/what are your favorite media sources that ...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4      Blogs (Towards Data Science, Analytics Vidhya,...
# ...                                                  ...
# 23993                                                NaN
# 23994                                                NaN
# 23995                                                NaN
# 23996                                                NaN
# 23997                                                NaN
#
#                                                    Q44_9  \
# 0      Who/what are your favorite media sources that ...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 23993  Journal Publications (peer-reviewed journals, ...
# 23994                                                NaN
# 23995                                                NaN
# 23996                                                NaN
# 23997                                                NaN
#
#                                                   Q44_10  \
# 0      Who/what are your favorite media sources that ...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 23993                                                NaN
# 23994                                                NaN
# 23995                                                NaN
# 23996                                                NaN
# 23997                                                NaN
#
#                                                   Q44_11  \
# 0      Who/what are your favorite media sources that ...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 23993                                                NaN
# 23994                                                NaN
# 23995                                                NaN
# 23996                                                NaN
# 23997                                                NaN
#
#                                                   Q44_12
# 0      Who/what are your favorite media sources that ...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 23993                                                NaN
# 23994                                                NaN
# 23995                                                NaN
# 23996                                                NaN
# 23997                                              Other
#
# [23998 rows x 296 columns]

# %% [markdown]
# # EDA

# %% [markdown]
# # Data Cleaning

# %%
df
# Out:
#       Gender Home Location Level of Education  Age(Years)  Number of Subjects  \
# 0       Male         Urban     Under Graduate          18                  11
# 1       Male         Urban     Under Graduate          19                   7
# 2       Male         Rural     Under Graduate          18                   5
# 3       Male         Urban     Under Graduate          18                   5
# 4       Male         Rural     Under Graduate          18                   5
# ...      ...           ...                ...         ...                 ...
# 1028  Female         Rural     Under Graduate          19                   3
# 1029  Female         Rural     Under Graduate          20                   6
# 1030  Female         Rural     Under Graduate          20                   3
# 1031  Female         Rural     Under Graduate          19                   6
# 1032  Female         Urban     Under Graduate          20                   6
#
#      Device type used to attend classes Economic status  Family size  \
# 0                                Laptop    Middle Class            4
# 1                                Laptop    Middle Class            4
# 2                                Laptop    Middle Class            5
# 3                                Laptop    Middle Class            4
# 4                                Laptop    Middle Class            4
# ...                                 ...             ...          ...
# 1028                             Mobile    Middle Class            6
# 1029                            Desktop    Middle Class            3
# 1030                             Mobile    Middle Class            3
# 1031                             Mobile    Middle Class            2
# 1032                             Laptop    Middle Class            4
#
#       Internet facility in your locality Are you involved in any sports?  ...  \
# 0                                      5                              No  ...
# 1                                      1                             Yes  ...
# 2                                      2                              No  ...
# 3                                      4                             Yes  ...
# 4                                      3                              No  ...
# ...                                  ...                             ...  ...
# 1028                                   5                             Yes  ...
# 1029                                   1                              No  ...
# 1030                                   2                              No  ...
# 1031                                   3                             Yes  ...
# 1032                                   3                              No  ...
#
#      Time spent on social media (Hours)  Interested in Gaming?  \
# 0                                     1                     No
# 1                                     1                    Yes
# 2                                     1                     No
# 3                                     2                     No
# 4                                     2                    Yes
# ...                                 ...                    ...
# 1028                                  4                    Yes
# 1029                                  2                    Yes
# 1030                                  3                     No
# 1031                                  2                    Yes
# 1032                                  1                    Yes
#
#       Have separate room for studying?  Engaged in group studies?  \
# 0                                   No                         No
# 1                                  Yes                         No
# 2                                  Yes                         No
# 3                                   No                        yes
# 4                                  Yes                        yes
# ...                                ...                        ...
# 1028                               Yes                        yes
# 1029                               Yes                         No
# 1030                               Yes                        yes
# 1031                                No                         No
# 1032                               Yes                        yes
#
#      Average marks scored before pandemic in traditional classroom  \
# 0                                                91-100
# 1                                                91-100
# 2                                                 71-80
# 3                                                91-100
# 4                                                 81-90
# ...                                                 ...
# 1028                                             91-100
# 1029                                              71-80
# 1030                                              71-80
# 1031                                              61-70
# 1032                                              81-90
#
#      Your interaction in online mode  \
# 0                                  1
# 1                                  1
# 2                                  1
# 3                                  1
# 4                                  3
# ...                              ...
# 1028                               4
# 1029                               5
# 1030                               2
# 1031                               3
# 1032                               5
#
#      Clearing doubts with faculties in online mode Interested in?  \
# 0                                                1      Practical
# 1                                                1         Theory
# 2                                                1           Both
# 3                                                2         Theory
# 4                                                3           Both
# ...                                            ...            ...
# 1028                                             4         Theory
# 1029                                             5         Theory
# 1030                                             2         Theory
# 1031                                             3           Both
# 1032                                             4      Practical
#
#       Performance in online  Your level of satisfaction in Online Education
# 0                         6                                         Average
# 1                         3                                             Bad
# 2                         6                                             Bad
# 3                         4                                             Bad
# 4                         6                                         Average
# ...                     ...                                             ...
# 1028                      8                                         Average
# 1029                     10                                         Average
# 1030                      6                                         Average
# 1031                      6                                            Good
# 1032                     10                                         Average
#
# [1033 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1033 entries, 0 to 1032
# Data columns (total 23 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   Gender                                                         1033 non-null   object
#  1   Home Location                                                  1033 non-null   object
#  2   Level of Education                                             1033 non-null   object
#  3   Age(Years)                                                     1033 non-null   int64
#  4   Number of Subjects                                             1033 non-null   int64
#  5   Device type used to attend classes                             1033 non-null   object
#  6   Economic status                                                1033 non-null   object
#  7   Family size                                                    1033 non-null   int64
#  8   Internet facility in your locality                             1033 non-null   int64
#  9   Are you involved in any sports?                                1033 non-null   object
#  10  Do elderly people monitor you?                                 1033 non-null   object
#  11  Study time (Hours)                                             1033 non-null   int64
#  12  Sleep time (Hours)                                             1033 non-null   int64
#  13  Time spent on social media (Hours)                             1033 non-null   int64
#  14  Interested in Gaming?                                          1033 non-null   object
#  15  Have separate room for studying?                               1033 non-null   object
#  16  Engaged in group studies?                                      1033 non-null   object
#  17  Average marks scored before pandemic in traditional classroom  1033 non-null   object
#  18  Your interaction in online mode                                1033 non-null   int64
#  19  Clearing doubts with faculties in online mode                  1033 non-null   int64
#  20  Interested in?                                                 1033 non-null   object
#  21  Performance in online                                          1033 non-null   int64
#  22  Your level of satisfaction in Online Education                 1033 non-null   object
# dtypes: int64(10), object(13)
# memory usage: 185.7+ KB

# %% [markdown]
# **missing data**

# %%
df.isna().sum()
# Out:
# Gender                                                           0
# Home Location                                                    0
# Level of Education                                               0
# Age(Years)                                                       0
# Number of Subjects                                               0
# Device type used to attend classes                               0
# Economic status                                                  0
# Family size                                                      0
# Internet facility in your locality                               0
# Are you involved in any sports?                                  0
# Do elderly people monitor you?                                   0
# Study time (Hours)                                               0
# Sleep time (Hours)                                               0
# Time spent on social media (Hours)                               0
# Interested in Gaming?                                            0
# Have separate room for studying?                                 0
# Engaged in group studies?                                        0
# Average marks scored before pandemic in traditional classroom    0
# Your interaction in online mode                                  0
# Clearing doubts with faculties in online mode                    0
# Interested in?                                                   0
# Performance in online                                            0
# Your level of satisfaction in Online Education                   0
# dtype: int64

# %% [markdown]
# **remove duplicate**

# %%
df.drop_duplicates()
# Out:
#       Gender Home Location Level of Education  Age(Years)  Number of Subjects  \
# 0       Male         Urban     Under Graduate          18                  11
# 1       Male         Urban     Under Graduate          19                   7
# 2       Male         Rural     Under Graduate          18                   5
# 3       Male         Urban     Under Graduate          18                   5
# 4       Male         Rural     Under Graduate          18                   5
# ...      ...           ...                ...         ...                 ...
# 1028  Female         Rural     Under Graduate          19                   3
# 1029  Female         Rural     Under Graduate          20                   6
# 1030  Female         Rural     Under Graduate          20                   3
# 1031  Female         Rural     Under Graduate          19                   6
# 1032  Female         Urban     Under Graduate          20                   6
#
#      Device type used to attend classes Economic status  Family size  \
# 0                                Laptop    Middle Class            4
# 1                                Laptop    Middle Class            4
# 2                                Laptop    Middle Class            5
# 3                                Laptop    Middle Class            4
# 4                                Laptop    Middle Class            4
# ...                                 ...             ...          ...
# 1028                             Mobile    Middle Class            6
# 1029                            Desktop    Middle Class            3
# 1030                             Mobile    Middle Class            3
# 1031                             Mobile    Middle Class            2
# 1032                             Laptop    Middle Class            4
#
#       Internet facility in your locality Are you involved in any sports?  ...  \
# 0                                      5                              No  ...
# 1                                      1                             Yes  ...
# 2                                      2                              No  ...
# 3                                      4                             Yes  ...
# 4                                      3                              No  ...
# ...                                  ...                             ...  ...
# 1028                                   5                             Yes  ...
# 1029                                   1                              No  ...
# 1030                                   2                              No  ...
# 1031                                   3                             Yes  ...
# 1032                                   3                              No  ...
#
#      Time spent on social media (Hours)  Interested in Gaming?  \
# 0                                     1                     No
# 1                                     1                    Yes
# 2                                     1                     No
# 3                                     2                     No
# 4                                     2                    Yes
# ...                                 ...                    ...
# 1028                                  4                    Yes
# 1029                                  2                    Yes
# 1030                                  3                     No
# 1031                                  2                    Yes
# 1032                                  1                    Yes
#
#       Have separate room for studying?  Engaged in group studies?  \
# 0                                   No                         No
# 1                                  Yes                         No
# 2                                  Yes                         No
# 3                                   No                        yes
# 4                                  Yes                        yes
# ...                                ...                        ...
# 1028                               Yes                        yes
# 1029                               Yes                         No
# 1030                               Yes                        yes
# 1031                                No                         No
# 1032                               Yes                        yes
#
#      Average marks scored before pandemic in traditional classroom  \
# 0                                                91-100
# 1                                                91-100
# 2                                                 71-80
# 3                                                91-100
# 4                                                 81-90
# ...                                                 ...
# 1028                                             91-100
# 1029                                              71-80
# 1030                                              71-80
# 1031                                              61-70
# 1032                                              81-90
#
#      Your interaction in online mode  \
# 0                                  1
# 1                                  1
# 2                                  1
# 3                                  1
# 4                                  3
# ...                              ...
# 1028                               4
# 1029                               5
# 1030                               2
# 1031                               3
# 1032                               5
#
#      Clearing doubts with faculties in online mode Interested in?  \
# 0                                                1      Practical
# 1                                                1         Theory
# 2                                                1           Both
# 3                                                2         Theory
# 4                                                3           Both
# ...                                            ...            ...
# 1028                                             4         Theory
# 1029                                             5         Theory
# 1030                                             2         Theory
# 1031                                             3           Both
# 1032                                             4      Practical
#
#       Performance in online  Your level of satisfaction in Online Education
# 0                         6                                         Average
# 1                         3                                             Bad
# 2                         6                                             Bad
# 3                         4                                             Bad
# 4                         6                                         Average
# ...                     ...                                             ...
# 1028                      8                                         Average
# 1029                     10                                         Average
# 1030                      6                                         Average
# 1031                      6                                            Good
# 1032                     10                                         Average
#
# [1033 rows x 23 columns]

# %%
#remove the top row 
data=data.iloc[1:,:]
data
# Out:
#       Duration (in seconds)     Q2     Q3                        Q4   Q5  \
# 1                       121  30-34    Man                     India   No
# 2                       462  30-34    Man                   Algeria   No
# 3                       293  18-21    Man                     Egypt  Yes
# 4                       851  55-59    Man                    France   No
# 5                       232  45-49    Man                     India  Yes
# ...                     ...    ...    ...                       ...  ...
# 23993                   331  22-24    Man  United States of America  Yes
# 23994                   330  60-69    Man  United States of America  Yes
# 23995                   860  25-29    Man                    Turkey   No
# 23996                   597  35-39  Woman                    Israel   No
# 23997                   303  18-21    Man                     India  Yes
#
#            Q6_1 Q6_2                  Q6_3      Q6_4 Q6_5  ... Q44_3  \
# 1           NaN  NaN                   NaN       NaN  NaN  ...   NaN
# 2           NaN  NaN                   NaN       NaN  NaN  ...   NaN
# 3      Coursera  edX                   NaN  DataCamp  NaN  ...   NaN
# 4      Coursera  NaN  Kaggle Learn Courses       NaN  NaN  ...   NaN
# 5           NaN  NaN                   NaN       NaN  NaN  ...   NaN
# ...         ...  ...                   ...       ...  ...  ...   ...
# 23993       NaN  NaN                   NaN       NaN  NaN  ...   NaN
# 23994       NaN  NaN                   NaN       NaN  NaN  ...   NaN
# 23995       NaN  NaN                   NaN  DataCamp  NaN  ...   NaN
# 23996       NaN  NaN  Kaggle Learn Courses       NaN  NaN  ...   NaN
# 23997       NaN  NaN                   NaN       NaN  NaN  ...   NaN
#
#                                  Q44_4  \
# 1                                  NaN
# 2                                  NaN
# 3      Kaggle (notebooks, forums, etc)
# 4      Kaggle (notebooks, forums, etc)
# 5                                  NaN
# ...                                ...
# 23993  Kaggle (notebooks, forums, etc)
# 23994                              NaN
# 23995  Kaggle (notebooks, forums, etc)
# 23996                              NaN
# 23997                              NaN
#
#                                                    Q44_5  \
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4      Course Forums (forums.fast.ai, Coursera forums...
# 5                                                    NaN
# ...                                                  ...
# 23993                                                NaN
# 23994                                                NaN
# 23995                                                NaN
# 23996                                                NaN
# 23997                                                NaN
#
#                                                    Q44_6  \
# 1                                                    NaN
# 2                                                    NaN
# 3      YouTube (Kaggle YouTube, Cloud AI Adventures, ...
# 4                                                    NaN
# 5                                                    NaN
# ...                                                  ...
# 23993  YouTube (Kaggle YouTube, Cloud AI Adventures, ...
# 23994  YouTube (Kaggle YouTube, Cloud AI Adventures, ...
# 23995  YouTube (Kaggle YouTube, Cloud AI Adventures, ...
# 23996  YouTube (Kaggle YouTube, Cloud AI Adventures, ...
# 23997                                                NaN
#
#                                                    Q44_7  \
# 1                                                    NaN
# 2                                                    NaN
# 3      Podcasts (Chai Time Data Science, O’Reilly Dat...
# 4                                                    NaN
# 5                                                    NaN
# ...                                                  ...
# 23993  Podcasts (Chai Time Data Science, O’Reilly Dat...
# 23994                                                NaN
# 23995                                                NaN
# 23996                                                NaN
# 23997                                                NaN
#
#                                                    Q44_8  \
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4      Blogs (Towards Data Science, Analytics Vidhya,...
# 5      Blogs (Towards Data Science, Analytics Vidhya,...
# ...                                                  ...
# 23993                                                NaN
# 23994                                                NaN
# 23995                                                NaN
# 23996                                                NaN
# 23997                                                NaN
#
#                                                    Q44_9 Q44_10 Q44_11 Q44_12
# 1                                                    NaN    NaN    NaN    NaN
# 2                                                    NaN    NaN    NaN    NaN
# 3                                                    NaN    NaN    NaN    NaN
# 4                                                    NaN    NaN    NaN    NaN
# 5                                                    NaN    NaN    NaN    NaN
# ...                                                  ...    ...    ...    ...
# 23993  Journal Publications (peer-reviewed journals, ...    NaN    NaN    NaN
# 23994                                                NaN    NaN    NaN    NaN
# 23995                                                NaN    NaN    NaN    NaN
# 23996                                                NaN    NaN    NaN    NaN
# 23997                                                NaN    NaN    NaN  Other
#
# [23997 rows x 296 columns]

# %%
Questions={}
#create list of questions 
#in dictnory fromkeys mthod need (key,value) to create dictnory
qnum=dict.fromkeys([i.split("_")[0]for i in data.columns])
qnum
# Out:
# {'Duration (in seconds)': None,
#  'Q2': None,
#  'Q3': None,
#  'Q4': None,
#  'Q5': None,
#  'Q6': None,
#  'Q7': None,
#  'Q8': None,
#  'Q9': None,
#  'Q10': None,
#  'Q11': None,
#  'Q12': None,
#  'Q13': None,
#  'Q14': None,
#  'Q15': None,
#  'Q16': None,
#  'Q17': None,
#  'Q18': None,
#  'Q19': None,
#  'Q20': None,
#  'Q21': None,
#  'Q22': None,
#  'Q23': None,
#  'Q24': None,
#  'Q25': None,
#  'Q26': None,
#  'Q27': None,
#  'Q28': None,
#  'Q29': None,
#  'Q30': None,
#  'Q31': None,
#  'Q32': None,
#  'Q33': None,
#  'Q34': None,
#  'Q35': None,
#  'Q36': None,
#  'Q37': None,
#  'Q38': None,
#  'Q39': None,
#  'Q40': None,
#  'Q41': None,
#  'Q42': None,
#  'Q43': None,
#  'Q44': None}

# %% [markdown]
# # Feature Engineering

# %%
#add data for each question to key value pairs in dictionary
for i in qnum: 
    if i in [ 'Q2','Q3','Q4','Q5']:
        Questions[i]=data[i] #uestions[i]=key and  data[i]= Value
    else:
        #startswith() method returns True if a string starts with the specified prefix(string). If not, it returns False.
        Questions[i]=data[[q for q in data.columns if q.startswith(i)]]

# %%
data["Q23"]
# Out:
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                 Data Scientist
# 5                            NaN
#                   ...
# 23993                        NaN
# 23994                        NaN
# 23995    Engineer (non-software)
# 23996         Research Scientist
# 23997                        NaN
# Name: Q23, Length: 23997, dtype: object

# %%
columns=df.iloc[20]
columns
# Out:
# Gender                                                                    Male
# Home Location                                                            Urban
# Level of Education                                               Post Graduate
# Age(Years)                                                                  24
# Number of Subjects                                                          20
# Device type used to attend classes                                      Laptop
# Economic status                                                           Poor
# Family size                                                                  6
# Internet facility in your locality                                           3
# Are you involved in any sports?                                             No
# Do elderly people monitor you?                                              No
# Study time (Hours)                                                           8
# Sleep time (Hours)                                                           8
# Time spent on social media (Hours)                                           2
# Interested in Gaming?                                                       No
# Have separate room for studying?                                            No
# Engaged in group studies?                                                   No
# Average marks scored before pandemic in traditional classroom            81-90
# Your interaction in online mode                                              2
# Clearing doubts with faculties in online mode                                3
# Interested in?                                                       Practical
# Performance in online                                                        4
# Your level of satisfaction in Online Education                             Bad
# Name: 20, dtype: object

# %%
df.columns
# Out:
# Index(['Gender', 'Home Location', 'Level of Education', 'Age(Years)',
#        'Number of Subjects', 'Device type used to attend classes',
#        'Economic status', 'Family size', 'Internet facility in your locality',
#        'Are you involved in any sports?', 'Do elderly people monitor you?',
#        'Study time (Hours)', 'Sleep time (Hours)',
#        'Time spent on social media (Hours)', 'Interested in Gaming?',
#        'Have separate room for studying?', 'Engaged in group studies?',
#        'Average marks scored before pandemic in traditional classroom',
#        'Your interaction in online mode',
#        'Clearing doubts with faculties in online mode', 'Interested in?',
#        'Performance in online',
#        'Your level of satisfaction in Online Education'],
#       dtype='object')

# %%
# x=df["Your level of satisfaction in Online Education"]
# y=df.iloc[:,0:22]

# %%
# from sklearn.feature_selection import SelectKBest, chi2, f_classif

# # chi-square
# top_10_features = SelectKBest(chi2, k=16).fit_transform(x, y)

# or ANOVA
# top_10_features = SelectKBest(f_classif, k=10).fit_transform(x, y)

# %% [markdown]
# **Which question i peck to this analysis:**
#
# 1.Home Location.
#
# 2.Level of Education?
#
# 3.Device type used to attend classes?
#
# 4.Internet facility in your locality?
#
# 5.Do elderly people monitor you?
#
# 6.Time spent on social media (Hours)?
#
# 7.Engaged in group studies?
#
# 8.Clearing doubts with faculties in online mode?
#
# 9.Interested in?
#
# 10.Performance in online?
#
# 11.Your level of satisfaction in Online Education?

# %%
#Create new column
df["How much time do you typically spend on the platform"]=df["Study time (Hours)"]

# %%
df["On a scale of 5 how easy is it to find is looking for"]=df["Clearing doubts with faculties in online mode"]

# %% [markdown]
# # univariate, bivariate and multivariate descriptive statistics.

# %% [markdown]
# **Home Location**

# %%
#  px.histogram(df, x="Home Location", color="Home Location")

# %% [markdown]
# # Q1
# **Level of education?**

# %%
fig = px.pie(df, names='Level of Education')
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="d5b21247-23db-4ee1-ad6f-166e4257d246" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d5b21247-23db-4ee1-ad6f-166e4257d246")) {                    Plotly.newPlot(                        "d5b21247-23db-4ee1-ad6f-166e4257d246",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Level of Education=%{label}<extra></extra>","labels":["Under Graduate","Under Graduate","Under Graduate","Under Graduate","Under Graduate","Under Graduate","Under Graduate","Under Graduate","Under Graduate","Under Graduate","Under Graduate","Post Graduate","Under Graduate","Under Graduate","School","School","Post Graduate","Post Graduate","School","Under Graduate","Post Graduate","Post Graduate","School","Post Graduate","Under Graduate","Post Graduate","Under Graduate","Under Graduate","Under Graduate","Under Graduate","Under Graduate","School","Post Graduate","Under Graduate","Under Graduate","Post Graduate","Under Graduate","Under Graduate","Post Graduate","Under Graduate","Post Graduate","School","Post Graduate","Under Graduate","Under Graduate","Under Graduate","Post Graduate","Under Graduate","Post Graduate","Post Graduate","School","Post Graduate","Under Graduate","Post Graduate","Post Graduate","Post Graduate","Post Graduate","Post Graduate","Under Graduate","Post Graduate","Under Graduate","Post Graduate","Post Graduate","Under Graduate","Under Graduate","Under Graduate","Under Graduate","Under Graduate","Under Graduate","Post Graduate","Under Graduate","Under Graduate","Under Graduate","Post Graduate","Post Graduate","Post Graduate","Under Graduate","Post Graduate","Under Graduate","Under Graduate","Under Graduate","Post Graduate","Under Graduate","Under Graduate","Under Graduate","Post Graduate","Under Graduate","Under Graduate","Under Graduate","Post Graduate","Under Graduate","Under Graduate","Under Graduate","Under Graduate","Post Graduate","Under Graduate","Under Graduate","Post Graduate","Under Graduate","School","Under Graduate","Under Graduate","Under Graduate","Under Graduate","Under Graduate","Under Graduate","Post Graduate","Under Graduate","Under Graduate","Under Graduate","Post Graduate","Under Graduate","Under Graduate","Under Graduate","Under Graduate","Under Graduate","School","Under Graduate","Under Graduate","Under Graduate","Under Graduate","Under Graduate","Post Graduate","Under Graduate","Under Graduate","Under Graduate","Under Graduate","Under Graduate","Under Graduate","Under Graduate","Under Graduate","Under Graduate","Under Graduate","Under Graduate","Under Graduate","Under Graduate","Post Graduate","Under Graduate","Under Graduate","Under Graduate","Under Graduate","Under Graduate","Under Graduate","Under Graduate","Under Graduate","Post Graduate","School","Under Graduate","Under Graduate","Under Graduate","Under Graduate","School","Under Graduate","Post Graduate","Under Graduate","Under Graduate","Under Graduate","Under Graduate","Under Graduate","Under Graduate","School","Under Graduate","Under Graduate","Under Graduate","School","Under Graduate","Under Graduate","Under Graduate","Under Graduate","Under Graduate","Under Graduate","Under Graduate","Under Graduate","Under Graduate","Under Graduate","Under Graduate","Under Graduate","Under Graduate","Under Graduate","Under Graduate","Under Graduate","Under Graduate","Under Graduate","Under Graduate","School","Under Graduate","Under Graduate","Under Graduate","Under Graduate","Under Graduate","Under Graduate","Under Graduate","Under Graduate","Under Graduate","Under Graduate","Under Graduate","Under Graduate","Under Graduate","School","Under Graduate","School","Under Graduate","Under Graduate","Under Graduate","School","School","Under Graduate","Under Graduate","Under ...

# %% [markdown]
# # Q2
# **How much time is spent spent on e-learning platform?**

# %%
# df["How much time do you typically spend on the platform"]=df["Study time (Hours)"]

# %%
fig = px.pie(df, names='How much time do you typically spend on the platform')
fig.show()
# Out:
# <div>                            <div id="ae761231-ec9e-4fb4-aec6-281b060d0bb9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ae761231-ec9e-4fb4-aec6-281b060d0bb9")) {                    Plotly.newPlot(                        "ae761231-ec9e-4fb4-aec6-281b060d0bb9",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"How much time do you typically spend on the platform=%{label}<extra></extra>","labels":[3,7,6,3,8,3,2,4,6,4,5,3,7,2,5,5,8,5,7,5,8,2,6,7,4,7,6,1,3,5,6,6,4,5,4,4,8,3,2,7,1,4,3,7,4,3,3,4,3,6,1,1,2,5,6,4,2,5,5,4,4,4,5,3,5,5,8,2,6,4,4,3,5,2,5,5,4,6,6,2,2,5,6,10,9,4,1,6,4,2,6,5,5,2,6,6,1,7,4,2,1,2,3,5,1,4,4,5,5,3,5,3,6,10,4,1,3,5,3,3,8,7,5,6,4,2,3,3,7,4,2,3,4,8,4,3,4,5,8,3,3,5,7,2,5,4,4,5,8,5,2,2,10,2,5,6,5,3,6,4,2,5,6,3,1,4,5,4,2,5,1,2,5,1,4,1,4,4,7,7,3,8,1,4,1,2,2,8,4,2,6,4,4,7,5,7,9,5,4,10,5,6,9,5,4,8,6,5,10,6,3,3,2,4,5,5,4,1,8,4,3,3,3,3,4,4,5,3,3,3,2,2,4,3,7,4,3,3,2,4,8,10,5,3,4,2,1,2,3,2,7,3,3,1,2,6,2,10,4,8,2,3,3,5,3,4,5,8,1,4,10,6,10,6,3,6,2,6,3,2,3,2,4,4,4,6,3,6,4,1,7,2,6,2,2,3,6,4,7,1,3,3,5,3,3,3,2,9,4,8,6,8,5,6,5,10,5,6,5,3,2,3,3,3,1,6,2,4,4,2,1,3,5,5,2,1,4,1,6,4,10,2,5,4,4,2,5,5,6,1,7,6,4,3,4,1,3,3,4,3,3,5,4,4,3,3,2,1,6,3,2,
,4,2,5,2,2,2,3,3,3,2,3,3,2,3,3,2,1,5,4,3,3,3,3,4,4,3,3,5,3,2,2,2,4,4,3,4,1,2,3,3,4,4,2,3,4,3,2,5,2,3,4,3,3,5,5,4,3,4,3,3,3,2,3,5,3,4,1,1,3,4,4,1,3,3,2,3,3,4,3,2,3,1,1,3,4,2,1,4,1,5,2,5,1,5,5,4,5,3,5,4,4,1,1,3,4,2,5,5,4,2,3,3,4,4,1,3,1,1,4,2,4,4,3,4,2,1,2,2,1,3,3,2,2,3,1,4,3,2,1,3,4,5,4,5,3,2,2,2,1,3,1,1,2,2,1,1,3,1,2,1,1,5,1,1,2,3,1,5,1,1,2,3,3,2,1,3,3,4,2,1,5,5,2,3,3,3,2,4,4,3,4,2,5,3,2,5,1,5,2,3,5,5,4,4,3,4,4,3,5,4,2,3,2,3,2,3,3,1,4,4,4,5,5,3,4,5,2,3,4],"legendgroup":"","name":"","showlegend":true,"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#f ...

# %% [markdown]
# # Q5
# What feature are important on the learning platfrom?

# %%
roles={}
for i in data["Q23"].unique():
  roles[i]=data[data["Q23"]==i]

# %%
feature=["Easy-to-use-interface","The syllabus and and materials","Notification and reminders","Privacy with identical functionality","Easy-to-find informatin","Fast response time","Color palette,Brightness,Contrast,Icon,etc.."]

# %%
#all education graph
edu =data.Q8.value_counts()
edu.index
# Out:
# Index(['Master’s degree', 'Bachelor’s degree', 'Doctoral degree',
#        'Some college/university study without earning a bachelor’s degree',
#        'I prefer not to answer', 'Professional doctorate',
#        'No formal education past high school'],
#       dtype='object')

# %%
edu.index=feature
fig=go.Figure(go.Bar(x=edu.index,y=edu.values))
fig.show()
# Out:
# <div>                            <div id="4b01b377-0717-43e0-b128-e5bcdd756564" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4b01b377-0717-43e0-b128-e5bcdd756564")) {                    Plotly.newPlot(                        "4b01b377-0717-43e0-b128-e5bcdd756564",                        [{"x":["Easy-to-use-interface","The syllabus and and materials","Notification and reminders","Privacy with identical functionality","Easy-to-find informatin","Fast response time","Color palette,Brightness,Contrast,Icon,etc.."],"y":[9142,7625,2657,1431,1394,585,564],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pat ...
#
# var gd = document.getElementById('4b01b377-0717-43e0-b128-e5bcdd756564');
# var x = new MutationObserver(function (mutations, observer) {{

# %% [markdown]
# # Q6
# what frustate student when using online study and seeiking information?

# %%
DS_Edu=roles["Data Scientist"].Q8.value_counts()
#edu.index show the first column values and edu.values show the second column values

# %%
frustate=["Need time to get used to with","Boring interface and icon","Complicated interface","Take time to find the night information","slow responding time","Can't find the right courses","Technology issues"]

# %%
DS_Edu.index=frustate
frus=DS_Edu.index

# %%
fig=go.Figure(go.Bar(x=frus,y=DS_Edu.values))
fig.show()
# Out:
# <div>                            <div id="995a87a1-91f9-449d-b6f5-5995ffe4eac6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("995a87a1-91f9-449d-b6f5-5995ffe4eac6")) {                    Plotly.newPlot(                        "995a87a1-91f9-449d-b6f5-5995ffe4eac6",                        [{"x":["Need time to get used to with","Boring interface and icon","Complicated interface","Take time to find the night information","slow responding time","Can't find the right courses","Technology issues"],"y":[974,406,327,96,51,39,36],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay", ...
#
# var gd = document.getElementById('995a87a1-91f9-449d-b6f5-5995ffe4eac6');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = windo
